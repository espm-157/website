# %% [markdown]
# # `ibis` mutates and aggregates
#
# ### Learning Goals
#
# - use `group_by()` and `aggregate()` patterns to summarize data
# - use `mutate()` to create an new column that is a function of data from existing columns in a table.
# - use `order_by()` to arrange rows by one or more columns.

# %%
import ibis
from ibis import _
import ibis.selectors as s

con = ibis.duckdb.connect()

# %%
base_url = "https://huggingface.co/datasets/cboettig/ram_fisheries/resolve/main/v4.65/"

stock = con.read_csv(base_url + "stock.csv", nullstr="NA")
timeseries = con.read_csv(base_url + "timeseries.csv", nullstr="NA")
assessment = con.read_csv(base_url + "assessment.csv", nullstr="NA")

# %% [markdown]
# # Stock "assessments"
#
# The next thing we need to know is a stock assessment.

# %%
assessment
# Out:
# DatabaseTable: ibis_read_csv_ldxnvs2lbzcblprbeqrxubgcye
#   assessid       string
#   assessorid     string
#   stockid        string
#   stocklong      string
#   recorder       string
#   daterecorded   timestamp(6)
#   dateloaded     timestamp(6)
#   assessyear     string
#   assesssource   string
#   contacts       string
#   notes          string
#   pdffile        string
#   assess         int64
#   refpoints      int64
#   assessmethod   string
#   assesscomments string
#   xlsfilename    string
#   mostrecent     int64

# %% [markdown]
# Are some `stockid`s assessed multiple times? One intuitive idea is to `filter()` for a single stockid, and see if we get back multiple rows (multiple assessments).  Let's take a look at "COD2J3KL":

# %%
(assessment
 .filter(_.stockid == "COD2J3KL")
 .execute()
)
# Out:
#                                assessid assessorid   stockid  \
# 0         DFO-COD2J3KL-1959-2014-WATSON        DFO  COD2J3KL
# 1     DFO-NFLD-COD2J3KL-1850-2011-CHING   DFO-NFLD  COD2J3KL
# 2  DFO-NFLD-COD2J3KL-1959-2018-ASHBROOK   DFO-NFLD  COD2J3KL
# 3    DFO-NFLD-COD2J3KL-1959-2021-HIVELY   DFO-NFLD  COD2J3KL
#
#                                            stocklong  recorder daterecorded  \
# 0  Atlantic cod Southern Labrador-Eastern Newfoun...    WATSON   2016-02-25
# 1  Atlantic cod Southern Labrador-Eastern Newfoun...     CHING   2013-10-22
# 2  Atlantic cod Southern Labrador-Eastern Newfoun...  ASHBROOK   2019-06-20
# 3  Atlantic cod Southern Labrador-Eastern Newfoun...    HIVELY   2023-11-08
#
#   dateloaded assessyear                                       assesssource  \
# 0 2016-02-18  1959-2014  http://www.dfo-mpo.gc.ca/csas-sccs/publication...
# 1 2001-12-31  1850-2011                                               NULL
# 2 2019-08-22  1959-2018  http://www.dfo-mpo.gc.ca/csas-sccs/Publication...
# 3 2023-11-10  1959-2021                                               NULL
#
#   contacts                             notes  \
# 0     NULL                              NULL
# 1     NULL                              NULL
# 2     NULL                              NULL
# 3     NULL  Science Advisory Report 2022/041
#
#                                            pdffile  assess  refpoints  \
# 0                                             NULL       1          1
# 1  Stock Assesment of Northern (2J3KL) Cod in 2013       1          1
# 2                            AtlanticCod.2J3KL.pdf       1          1
# 3                                             NULL       1          1
#
#   assessmethod assesscomments  \
# 0        SURBA           NULL
# 1        SURBA           NULL
# 2          ICA           NULL
# 3          ICA           NULL
#
#                                          xlsfilename  mostrecent
# 0                WATSON_COD2J3KL_2014-DH-edited.xlsx           0
# 1  /home/srdbadmin/srdb/spreadsheets/CHING-COD2J3...           0
# 2              ASHBROOK-COD2J3KL-2018-DH-edited.xlsx           0
# 3                          CND_vers4.62_updates.xlsx         999

# %% [markdown]
# Indeed, it looks like their are four assessments of this stock, each conducted in different years and spanning different periods in time!  `filter()`ing for each possible stockid would be tedious though. These four assessments that correspond to this stockid

# %%
(assessment
 .group_by(_.stockid)
 .agg(n=_.count())
 .execute()
)
# Out:
#                stockid   n
# 0     CODIIIaW-IV-VIId  12
# 1             HERRNIRS  11
# 2     HERRNS-IIIa-VIId  11
# 3             POLLFAPL  11
# 4          WHITNS-VIId  11
# ...                ...  ..
# 1507         SSALMQUIN   1
# 1508     SPRAYVI-VIIbj   1
# 1509          TBSKAIXa   1
# 1510           TBSKAVI   1
# 1511         TBSKAVIIe   1
#
# [1512 rows x 2 columns]

# %%
assessment.group_by(_.stockid).order_by(_.assessyear).agg(assessid=_.assessid.last()).filter(_.stockid == "CODIIIaW-IV-VIId").execute()
# Out:
#             stockid                                         assessid
# 0  CODIIIaW-IV-VIId  WGNSSK-CODIIIaW-IV-VIId-1963-2021-ICESIMP2021-2

# %%
timeseries

# %%
stock
# Out:
# DatabaseTable: ibis_read_csv_aee33mgu3rfsnammlaymycd2lu
#   stockid         string
#   tsn             int64
#   scientificname  string
#   commonname      string
#   areaid          string
#   stocklong       string
#   region          string
#   primary_country string
#   primary_FAOarea int64
#   ISO3_code       string
#   GRSF_uuid       string
#   GRSF_areaid     string
#   inmyersdb       int64
#   myersstockid    string
#   state           string
